# %%
import pandas as pd
import numpy as np
import plotly
import cufflinks as cf
# %matplotlib inline

# %%
print(plotly.__version__)
# Out:
# 5.24.1

# %%
#https://github.com/santosjorge/cufflinks/blob/master/Cufflinks%20Tutorial%20-%20Chart%20Gallery.ipynb

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0  0.537154  0.278270 -0.788873  0.043081
# 1  0.454022  1.479304 -0.011201 -0.956344
# 2  0.245894  0.121298 -0.775838 -0.503688
# 3 -0.938191 -0.635615 -1.422801  0.743182
# 4  1.040106 -0.140293  1.872574  0.208448

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)

# %%
df2.iplot(kind='bar',x='Category',y='Values')

# %%
df.count().iplot(kind='bar')

# %%
df.iplot(kind='box')

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[50,40,30,20,10]})
df3.iplot(kind='surface',colorscale='rdylbu')

# %%
df.iplot(kind="hist", bins=50)

# %%
df.iplot(kind='bubble',x='A',y='B',size='C', colors=['blue'])

# %%
df.scatter_matrix()
